# %% [markdown]
# # Genetic Algorithms - Plotting

# %% [raw]
# This is a plotting module that reads from the persisted output of GeneticAlgorithm-v2.ipynb

# %%
# Plot Snapshots - Ex0
from matplotlib import cm
# Make data for manifold
X = np.arange(-1.5, 1.5, 0.05)
Y = np.arange(-1.5, 1.5, 0.05)
X, Y = np.meshgrid(X, Y)
Z = objective_function([X,Y])

# Make data for population
it = 10
snapshot_x = [ pop_x[0] for pop_x in  snapshot[it]]
snapshot_y = [ pop_x[1] for pop_x in  snapshot[it]]
snapshot_z = [ objective_function(pop_x) for pop_x in  snapshot[it]]

plt.figure(figsize=(10,10))
ax = plt.gcf().gca(projection='3d')
ax.plot_surface(X, Y, Z, cmap=cm.coolwarm, linewidth=0, antialiased=False, alpha=0.5)
ax.scatter(xs=snapshot_x, ys=snapshot_y, zs=snapshot_z, s=50, c='k', alpha=0.9)
plt.show()

# %%
# Plot Snapshots - Ex1
import numpy as np
from mpl_toolkits.mplot3d import Axes3D
import matplotlib.pyplot as plt

# Generate torus mesh
angle = np.linspace(0, TwoPi, 32)
theta, phi = np.meshgrid(angle, angle)
X, Y, Z = torus(theta, phi)

# Display the mesh
fig = plt.figure(figsize=(7,7))
ax = fig.gca(projection = '3d')
ax.set_xlim3d(-1, 1)
ax.set_ylim3d(-1, 1)
ax.set_zlim3d(-1, 1)
ax.plot_surface(X, Y, Z, color = 'w', rstride = 1, cstride = 1, alpha=0.5)

# plot population
it = 0
# population data
snapshot_theta = [ pop_x[0] for pop_x in  snapshot[it]]
snapshot_phi = [ pop_x[1] for pop_x in  snapshot[it]]
snapshot_x, snapshot_y, snapshot_z = torus(snapshot_theta, snapshot_phi)
ax.scatter(xs=snapshot_x, ys=snapshot_y, zs=snapshot_z, s=50, c='k', alpha=0.9)
# plot target
x0_x, x0_y, x0_z = torus(x0[0],x0[1])
ax.scatter(xs=x0_x, ys=x0_y, zs=x0_z, s=150, c='r', alpha=1.)

plt.show()

# %%
# ANIMATION Ex1 - Via FuncAnimate
# importig movie py libraries 
from matplotlib.animation import FuncAnimation
from matplotlib.animation import PillowWriter
import numpy as np
from mpl_toolkits.mplot3d import Axes3D
import matplotlib.pyplot as plt

# define figure
fig, ax = plt.subplots()
ax = fig.gca(projection = '3d')

# toroidal manifiold
angle = np.linspace(0, TwoPi, 32)
theta, phi = np.meshgrid(angle, angle)
X, Y, Z = torus(theta, phi)
    
# plot population
plot1 = ax.plot_surface(X, Y, Z, color = 'w', rstride = 1, cstride = 1, alpha=0.5)
plot2 = ax.scatter(xs=[],ys=[],zs=[])
plot3 = ax.scatter(xs=[],ys=[],zs=[])


def init():
    ax.set_xlim3d(-1, 1)
    ax.set_ylim3d(-1, 1)
    ax.set_zlim3d(-1, 1)
    return plot1, plot2, plot3

# method to get frames 
def update(it): 
    ax.clear(); ax.set_xlim3d(-1, 1); ax.set_ylim3d(-1, 1); ax.set_zlim3d(-1, 1)
    # population data
    snapshot_theta = [ pop_x[0] for pop_x in  snapshot[it]]
    snapshot_phi = [ pop_x[1] for pop_x in  snapshot[it]]
    snapshot_x, snapshot_y, snapshot_z = torus(snapshot_theta, snapshot_phi)
    # target point data
    x0_x, x0_y, x0_z = torus(x0[0], x0[1])
    # Set data
    plot1 = ax.plot_surface(X, Y, Z, color = 'w', rstride = 1, cstride = 1, alpha=0.5)
    plot2 = ax.scatter(xs=snapshot_x,ys=snapshot_y,zs=snapshot_z, s=50, c='k', alpha=0.9)
    plot3 = ax.scatter(xs=x0_x, ys=x0_y, zs=x0_z, s=150, c='r', alpha=1.)
    # returning plots 
    return plot1, plot2, plot3

# creating animation 
animation = FuncAnimation(fig, func=update, frames=np.arange(0, niter, 1), init_func=init) 

# save GIF
writergif = PillowWriter(fps=30, bitrate=True)
animation.save('filename2.gif',writer=writergif, dpi=100)

# save MP4
# animation.save('basic_animation.mp4', fps=30, extra_args=['-vcodec', 'libx264'])

plt.show()

# %%
# MOVIE EX0
# importig movie py libraries 
from moviepy.editor import VideoClip 
from moviepy.video.io.bindings import mplfig_to_npimage 

# duration of the video 
duration = niter

# matplot subplot 
fig, ax = plt.figure(figsize=(10,10)), plt.gcf().gca(projection='3d')

# method to get frames 
def make_frame(it): 
    # clear 
    ax.clear() 
    # population data
    it = int(it)
    snapshot_x = [ pop_x[0] for pop_x in  snapshot[it]]
    snapshot_y = [ pop_x[1] for pop_x in  snapshot[it]]
    snapshot_z = [ objective_function(pop_x) for pop_x in  snapshot[it]]
    # plotting
    ax.plot_surface(X, Y, Z, cmap=cm.coolwarm, linewidth=0, antialiased=False, alpha=0.5,)
    ax.scatter(xs=snapshot_x, ys=snapshot_y, zs=snapshot_z, s=50, c='k', alpha=1.,)
    # returning mumpy image 
    return mplfig_to_npimage(fig) 

# creating animation 
animation = VideoClip(make_frame, duration = duration) 

# displaying animation with auto paly and looping 
animation.ipython_display(fps = 1, loop = True, autoplay = True)

# %%
# MOVIE EX1
# importig movie py libraries 
from moviepy.editor import VideoClip 
from moviepy.video.io.bindings import mplfig_to_npimage 
from matplotlib.animation import FuncAnimation

import numpy as np
from mpl_toolkits.mplot3d import Axes3D
import matplotlib.pyplot as plt

# Generate torus mesh
angle = np.linspace(0, TwoPi, 32)
theta, phi = np.meshgrid(angle, angle)
X, Y, Z = torus(theta, phi)

# Display the mesh
fig = plt.figure(figsize=(7,7))
ax = fig.gca(projection = '3d')
ax.set_xlim3d(-1, 1)
ax.set_ylim3d(-1, 1)
ax.set_zlim3d(-1, 1)

# duration of the video 
duration = 50

# method to get frames 
def make_frame(it): 
    # clear 
    it = int(it)
    ax.clear(); ax.set_xlim3d(-1, 1); ax.set_ylim3d(-1, 1); ax.set_zlim3d(-1, 1)
    # population data
    snapshot_theta = [ pop_x[0] for pop_x in  snapshot[it]]
    snapshot_phi = [ pop_x[1] for pop_x in  snapshot[it]]
    snapshot_x, snapshot_y, snapshot_z = torus(snapshot_theta, snapshot_phi)
    # plot population
    ax.plot_surface(X, Y, Z, color = 'w', rstride = 1, cstride = 1, alpha=0.5)
    ax.scatter(xs=snapshot_x, ys=snapshot_y, zs=snapshot_z, s=50, alpha=0.9)
    # plot target
    x0_x, x0_y, x0_z = torus(x0[0], x0[1])
    ax.scatter(xs=x0_x, ys=x0_y, zs=x0_z, s=150, c='r', alpha=1.)
    # returning mumpy image 
    return mplfig_to_npimage(fig) 

# creating animation 
animation = VideoClip(make_frame, duration = duration) 

# displaying animation with auto paly and looping 
animation.ipython_display(fps = 5, loop = True, autoplay = True)

# %%
from matplotlib import cm

# Make data for manifold
X = np.arange(-1.5, 1.5, 0.05)
Y = np.arange(-1.5, 1.5, 0.05)
X, Y = np.meshgrid(X, Y)
Z = objective_function([X,Y])

plt.figure(figsize=(10,10))
ax = plt.gcf().gca(projection='3d')

it = 0
# population data
snapshot_x = [ pop_x[0] for pop_x in  snapshot[it]]
snapshot_y = [ pop_x[1] for pop_x in  snapshot[it]]
snapshot_z = [ objective_function(pop_x) for pop_x in  snapshot[it]]
# plotting
ax.plot_surface(X, Y, Z, cmap=cm.coolwarm, linewidth=0, antialiased=False, alpha=0.3,)
ax.scatter(xs=snapshot_x, ys=snapshot_y, zs=snapshot_z, s=50, c='k', alpha=1,)
plt.show()
